# %%
import pandas as pd

# %%
df = pd.read_csv('air_quality_no2.csv', index_col=0)

# %%
df['station_france'] = df['station_london'] * 2
df['station_germany'] = df['station_france'] * 2

# %%
df
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      station_france  station_germany
# datetime
# 2019-05-07 02:00:00            46.0             92.0
# ...

# %%
data = {
    'Name': ['Ram', 'Sita', 'Syam'],
    'Age': [50, 21, 120],
    'Marks': [600, 100, 250]
}

df = pd.DataFrame(data)

# %%
df.rename(columns = {'Name': 'Naam', 'Age': 'Umer', 'Marks': 'Anka'})
# Out:
#    Naam  Umer  Anka
# 0   Ram    50   600
# 1  Sita    21   100
# 2  Syam   120   250

# %%
df.rename(columns = str.upper)
# Out:
#    NAME  AGE  MARKS
# 0   Ram   50    600
# 1  Sita   21    100
# 2  Syam  120    250

# %%
df['Age'].mean()
# Out:
# np.float64(63.666666666666664)

# %%
df.agg({'Age': ['min', 'max', 'median', 'skew'], 'Marks': ['min', 'max', 'median', 'mean']})
# Out:
#                Age       Marks
# min      21.000000  100.000000
# max     120.000000  600.000000
# median   50.000000  250.000000
# skew      1.121233         NaN
# mean           NaN  316.666667

# %%
# Advanced Pandas
data = {
    'Name': ['Ram', 'Sita', 'Syam', 'Radha'],
    'Age': [25, 21, 25, 25],
    'Marks': [600, 100, 250, 400],
    'Gender': ['Male','Female','Male','Female']
}

df = pd.DataFrame(data)

# %%
df['Age'].mean()
# Out:
# np.float64(34.75)

# %%
df[['Age', 'Gender']].groupby('Gender').mean()
# Out:
#          Age
# Gender
# Female  32.0
# Male    37.5

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    32.0
# Male      37.5
# Name: Age, dtype: float64

# %%
df.sort_values('Age')
# Out:
#     Name  Age  Marks  Gender
# 1   Sita   21    100  Female
# 2   Syam   25    250    Male
# 3  Radha   43    400  Female
# 0    Ram   50    600    Male

# %%
df.sort_values(by = 'Age')
# Out:
#     Name  Age  Marks  Gender
# 1   Sita   21    100  Female
# 0    Ram   25    600    Male
# 2   Syam   25    250    Male
# 3  Radha   25    400  Female

# %%
df.sort_values(['Age', 'Gender'])
# Out:
#     Name  Age  Marks  Gender
# 1   Sita   21    100  Female
# 3  Radha   25    400  Female
# 0    Ram   25    600    Male
# 2   Syam   25    250    Male

# %%
df[df['Age'] == 21]
# Out:
#    Name  Age  Marks  Gender
# 1  Sita   21    100  Female

# %%
df_subset = df.sort_index().groupby('Gender').head(1)
df_subset
# Out:
#    Name  Age  Marks  Gender
# 0   Ram   25    600    Male
# 1  Sita   21    100  Female

# %%
df.groupby('Marks')['Marks'].count()
# Out:
# Marks
# 100    1
# 250    1
# 400    1
# 600    1
# Name: Marks, dtype: int64

# %%
df = pd.read_csv('air_quality_long.csv')

# %%
df['country'].unique()
# Out:
# array(['BE', 'GB', 'FR'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Antwerpen', 'London', 'Paris'], dtype=object)

# %%
df['location'].unique()
# Out:
# array(['BETR801', 'London Westminster', 'FR04014'], dtype=object)

# %%
df
# Out:
#            city country                   date.utc            location  \
# 0     Antwerpen      BE  2019-06-18 06:00:00+00:00             BETR801
# 1     Antwerpen      BE  2019-06-17 08:00:00+00:00             BETR801
# 2     Antwerpen      BE  2019-06-17 07:00:00+00:00             BETR801
# 3     Antwerpen      BE  2019-06-17 06:00:00+00:00             BETR801
# 4     Antwerpen      BE  2019-06-17 05:00:00+00:00             BETR801
# ...         ...     ...                        ...                 ...
# 5267     London      GB  2019-04-09 06:00:00+00:00  London Westminster
# 5268     London      GB  2019-04-09 05:00:00+00:00  London Westminster
# 5269     London      GB  2019-04-09 04:00:00+00:00  London Westminster
# 5270     London      GB  2019-04-09 03:00:00+00:00  London Westminster
# 5271     London      GB  2019-04-09 02:00:00+00:00  London Westminster
#
#      parameter  value   unit
# 0         pm25   18.0  µg/m³
# 1         pm25    6.5  µg/m³
# ...
