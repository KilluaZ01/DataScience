# %% [markdown]
# Deep Learning ( Implemented through neural networks )

# %%
import pandas as pd
mat = [['ram','12'],['hari','13']]

df = pd.DataFrame(mat)
df
# Out:
#       0   1
# 0   ram  12
# 1  hari  13

# %%
dic = {
    'Name': ['Arik','Nima','Zidan'],
    'Age': [20,21,22]
}

# %%
dic_df = pd.DataFrame(dic)
dic_df
# Out:
#     Name  Age
# 0   Arik   20
# 1   Nima   21
# 2  Zidan   22

# %%
dic_df['Age'].max()
# Out:
# 22

# %%
dic_df['Age'].min()
# Out:
# 20

# %%
dic_df['Age'].mean()
# Out:
# np.float64(21.0)

# %%
# Make pandas series
a = [20, 21, 22]

my_series = pd.Series(a, name = 'Ages')

my_series
# Out:
# 0    20
# 1    21
# 2    22
# Name: Ages, dtype: int64

# %%
my_series.max()
# Out:
# 22

# %%
type(dic_df[['Age','Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[dic_df['Age']>20]
# Out:
# <ipython-input-41-9504590d6999>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[dic_df['Age']>20]
#       0   1
# 1  hari  13

# %%
dic_df[dic_df['Age'].isin([20,22])]
# Out:
#     Name  Age
# 0   Arik   20
# 2  Zidan   22

# %%
dic_df[(dic_df['Age'] == 20) | (dic_df['Age'] == 22)]
# Out:
#     Name  Age
# 0   Arik   20
# 2  Zidan   22

# %%
# Notna returns the not null values (non empty rows)
dic_df[dic_df['Age'].notna()]
# Out:
#     Name  Age
# 0   Arik   20
# 1   Nima   21
# 2  Zidan   22

# %%
dic_df.loc[dic_df['Age'] == 21, 'Name']   # Filters both rows and columns
# Out:
# 1    Nima
# Name: Name, dtype: object

# %%
dic_df['Name']
# Out:
# 0     Arik
# 1     Nima
# 2    Zidan
# Name: Name, dtype: object

# %%
dic_df[dic_df['Name'].isin(['Nima','Arik'])]
# Out:
#    Name  Age
# 0  Arik   20
# 1  Nima   21

# %%
dic_df.loc[dic_df['Name'].isin(['Arik','Zidan']), ['Name','Age']]
# Out:
#     Name  Age
# 0   Arik   20
# 2  Zidan   22

# %%
dic_df.loc[(dic_df['Age'] == 21) | (dic_df['Age'] == 22), 'Age']
# Out:
# 1    21
# 2    22
# Name: Age, dtype: int64

# %%
dic_df.loc[(dic_df['Age'] == 21) | (dic_df['Name'] == 'Arik'), ('Name','Age')]
# Out:
#    Name  Age
# 0  Arik   20
# 1  Nima   21
